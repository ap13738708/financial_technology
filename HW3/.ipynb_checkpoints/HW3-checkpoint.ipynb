# %%
import tensorflow as tf

from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from tensorflow.keras import datasets
import matplotlib.pyplot as plt

import numpy as np
import os
import cv2 as cv
from imutils import build_montages
import pickle
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# ## Data preparation

# %%
mnist = tf.keras.datasets.fashion_mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ## Create CNN model

# %%
model = tf.keras.Sequential()
model.add(Conv2D(28, (3, 3), padding='same', activation='relu', input_shape=(28,28,1)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

# %%
checkpointer = tf.keras.callbacks.ModelCheckpoint(filepath="best_weights.hdf5", 
                               monitor = 'val_accuracy',
                               verbose=1, 
                               save_best_only=True)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 28, 28, 28)        280
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 28)        112
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 28)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 28)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 64)        16192
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,630,162
# Trainable params: 1,628,954
# Non-trainable params: 1,208
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Need to change the value
# history = model.fit(x_train[:,:,:, np.newaxis], 
#                     y_train, epochs=25, 
#                     callbacks=[checkpointer],
#                     validation_split=0.2)

# np.expand_dims(a, axis=1)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.4984 - accuracy: 0.8289
# Epoch 00001: val_accuracy improved from -inf to 0.88375, saving model to best_weights.hdf5
# 48000/48000 [==============================] - 188s 4ms/sample - loss: 0.4983 - accuracy: 0.8289 - val_loss: 0.3218 - val_accuracy: 0.8838
# Epoch 2/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.3473 - accuracy: 0.8733
# Epoch 00002: val_accuracy improved from 0.88375 to 0.88850, saving model to best_weights.hdf5
# 48000/48000 [==============================] - 185s 4ms/sample - loss: 0.3473 - accuracy: 0.8734 - val_loss: 0.3494 - val_accuracy: 0.8885
# Epoch 3/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.3163 - accuracy: 0.8843
# Epoch 00003: val_accuracy improved from 0.88850 to 0.90575, saving model to best_weights.hdf5
# 48000/48000 [==============================] - 181s 4ms/sample - loss: 0.3163 - accuracy: 0.8843 - val_loss: 0.2626 - val_accuracy: 0.9057
# Epoch 4/25
# 47968/48000 [============================>.] - ETA: 1s - loss: 0.2929 - accuracy: 0.8944
# Epoch 00004: val_accuracy did not improve from 0.90575
# 48000/48000 [==============================] - 1545s 32ms/sample - loss: 0.2929 - accuracy: 0.8944 - val_loss: 0.3098 - val_accuracy: 0.8990
# Epoch 5/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.2754 - accuracy: 0.8997
# Epoch 00005: val_accuracy did not improve from 0.90575
# 48000/48000 [==============================] - 180s 4ms/sample - loss: 0.2755 - accuracy: 0.8997 - val_loss: 0.2609 - val_accuracy: 0.9044
# Epoch 6/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.2623 - accuracy: 0.9055
# Epoch 00006: val_accuracy improved from 0.90575 to 0.91183, saving model to best_weights.hdf5
# 48000/48000 [==============================] - 180s 4ms/sample - loss: 0.2623 - accuracy: 0.9055 - val_loss: 0.2328 - val_accuracy: 0.9118
# Epoch 7/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.2530 - accuracy: 0.9070
# Epoch 00007: val_accuracy improved from 0.91183 to 0.91550, saving model to best_weights.hdf5
# 48000/48000 [==============================] - 180s 4ms/sample - loss: 0.2530 - accuracy: 0.9071 - val_loss: 0.2338 - val_accuracy: 0.9155
# Epoch 8/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.2482 - accuracy: 0.9087
# Epoch 00008: val_accuracy did not improve from 0.91550
# 48000/48000 [==============================] - 192s 4ms/sample - loss: 0.2481 - accuracy: 0.9087 - val_loss: 0.2538 - val_accuracy: 0.9103
# Epoch 9/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.2377 - accuracy: 0.9124
# Epoch 00009: val_accuracy improved from 0.91550 to 0.92283, saving model to best_weights.hdf5
# 48000/48000 [==============================] - 182s 4ms/sample - loss: 0.2377 - accuracy: 0.9124 - val_loss: 0.2186 - val_accuracy: 0.9228
# Epoch 10/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.2229 - accuracy: 0.9192
# Epoch 00010: val_accuracy did not improve from 0.92283
# 48000/48000 [==============================] - 181s 4ms/sample - loss: 0.2228 - accuracy: 0.9191 - val_loss: 0.2395 - val_accuracy: 0.9108
# Epoch 11/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.2176 - accuracy: 0.9205
# Epoch 00011: val_accuracy did not improve from 0.92283
# 48000/48000 [==============================] - 350s 7ms/sample - loss: 0.2176 - accuracy: 0.9205 - val_loss: 0.2334 - val_accuracy: 0.9221
# Epoch 12/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.2099 - accuracy: 0.9228
# Epoch 00012: val_accuracy improved from 0.92283 to 0.92383, saving model to best_weights.hdf5
# 48000/48000 [==============================] - 182s 4ms/sample - loss: 0.2100 - accuracy: 0.9228 - val_loss: 0.2115 - val_accuracy: 0.9238
# Epoch 13/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.2099 - accuracy: 0.9228
# Epoch 00013: val_accuracy did not improve from 0.92383
# 48000/48000 [==============================] - 180s 4ms/sample - loss: 0.2099 - accuracy: 0.9228 - val_loss: 0.2203 - val_accuracy: 0.9209
# Epoch 14/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1976 - accuracy: 0.9262
# Epoch 00014: val_accuracy did not improve from 0.92383
# 48000/48000 [==============================] - 180s 4ms/sample - loss: 0.1976 - accuracy: 0.9262 - val_loss: 0.2216 - val_accuracy: 0.9223
# Epoch 15/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1882 - accuracy: 0.9303
# Epoch 00015: val_accuracy improved from 0.92383 to 0.92775, saving model to best_weights.hdf5
# 48000/48000 [==============================] - 730s 15ms/sample - loss: 0.1882 - accuracy: 0.9304 - val_loss: 0.2229 - val_accuracy: 0.9277
# Epoch 16/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1932 - accuracy: 0.9285
# Epoch 00016: val_accuracy did not improve from 0.92775
# 48000/48000 [==============================] - 187s 4ms/sample - loss: 0.1932 - accuracy: 0.9284 - val_loss: 0.2966 - val_accuracy: 0.8967
# Epoch 17/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1898 - accuracy: 0.9285
# Epoch 00017: val_accuracy did not improve from 0.92775
# 48000/48000 [==============================] - 185s 4ms/sample - loss: 0.1897 - accuracy: 0.9285 - val_loss: 0.3161 - val_accuracy: 0.8963
# Epoch 18/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1790 - accuracy: 0.9333
# Epoch 00018: val_accuracy did not improve from 0.92775
# 48000/48000 [==============================] - 183s 4ms/sample - loss: 0.1790 - accuracy: 0.9333 - val_loss: 0.2290 - val_accuracy: 0.9165
# Epoch 19/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1744 - accuracy: 0.9350
# Epoch 00019: val_accuracy improved from 0.92775 to 0.92842, saving model to best_weights.hdf5
# 48000/48000 [==============================] - 181s 4ms/sample - loss: 0.1743 - accuracy: 0.9350 - val_loss: 0.2080 - val_accuracy: 0.9284
# Epoch 20/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1738 - accuracy: 0.9356
# Epoch 00020: val_accuracy improved from 0.92842 to 0.92950, saving model to best_weights.hdf5
# 48000/48000 [==============================] - 180s 4ms/sample - loss: 0.1737 - accuracy: 0.9357 - val_loss: 0.2307 - val_accuracy: 0.9295
# Epoch 21/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1685 - accuracy: 0.9367
# Epoch 00021: val_accuracy improved from 0.92950 to 0.92983, saving model to best_weights.hdf5
# 48000/48000 [==============================] - 180s 4ms/sample - loss: 0.1684 - accuracy: 0.9367 - val_loss: 0.2046 - val_accuracy: 0.9298
# Epoch 22/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1615 - accuracy: 0.9401
# Epoch 00022: val_accuracy did not improve from 0.92983
# 48000/48000 [==============================] - 179s 4ms/sample - loss: 0.1615 - accuracy: 0.9401 - val_loss: 0.2111 - val_accuracy: 0.9277
# Epoch 23/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1529 - accuracy: 0.9441
# Epoch 00023: val_accuracy improved from 0.92983 to 0.93225, saving model to best_weights.hdf5
# 48000/48000 [==============================] - 179s 4ms/sample - loss: 0.1529 - accuracy: 0.9441 - val_loss: 0.1960 - val_accuracy: 0.9323
# Epoch 24/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1532 - accuracy: 0.9432
# Epoch 00024: val_accuracy did not improve from 0.93225
# 48000/48000 [==============================] - 179s 4ms/sample - loss: 0.1532 - accuracy: 0.9432 - val_loss: 0.2488 - val_accuracy: 0.9195
# Epoch 25/25
# 47968/48000 [============================>.] - ETA: 0s - loss: 0.1533 - accuracy: 0.9428
# Epoch 00025: val_accuracy did not improve from 0.93225
# 48000/48000 [==============================] - 179s 4ms/sample - loss: 0.1532 - accuracy: 0.9428 - val_loss: 0.2626 - val_accuracy: 0.9146

# %%
model.load_weights('best_weights.hdf5')
model.save('shapes_cnn.h5')

# %%
with open('trainHistoryOld', 'wb') as file_pi:
        pickle.dump(history, file_pi)

# %% [markdown]
# ## Plot learning curve

# %%
test_loss, test_acc  = model.evaluate(x_test[:,:,:, np.newaxis], y_test, verbose=False)
print('Tested Acc: ', test_acc)
print('Tested Loss: ', test_loss)
# Out:
# Tested Acc:  0.9109
# Tested Loss:  0.28220323958843946

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Prediction

# %%
predictions = model.predict(x_test[:, :, :, np.newaxis])

# %%
predicted_args = np.argmax(predictions, axis=1)

# %%
i = 5

plt.xticks([])
plt.yticks([])
plt.imshow(x_test[i], cmap=plt.cm.binary)
plt.xlabel('predicted: {}, label: {}'.format(class_names[predicted_args[i]], class_names[y_test[i]]) )
# Out:
# Text(0.5, 0, 'predicted: Trouser, label: Trouser')

# %% [markdown]
# ## Plot activations of the first layer

# %%
layer_outputs = [layer.output for layer in model.layers] 
activation_model = tf.keras.Model(inputs=model.input, outputs=layer_outputs)

activations = activation_model.predict(x_test[:1000,:,:, np.newaxis]) 
# Returns a list of five Numpy arrays: one array per layer activation

first_layer_activation = activations[0]
print(first_layer_activation.shape)

# plt.matshow(first_layer_activation[0, :, :, 4], cmap='viridis')
plt.figure(figsize=(10,10))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(activations[0][0, :, :, i], cmap=plt.cm.binary)
plt.show()
# Out:
# (1000, 28, 28, 28)

# %% [markdown]
# ## Fashion MNIST classification

# %%
# initialize list of output images
images = []
 
# randomly select a few testing fashion items
random_choice = np.random.choice(np.arange(0, len(y_test)), size=(16,))
for i in random_choice:
    # classify the clothing
#     probs = model.predict(testX[np.newaxis, i])
#     prediction = probs.argmax(axis=1)
#     label = labelNames[prediction[0]]
 
    # otherwise we are using "channels_last" ordering
    image = (x_test[i] * 255).astype("uint8")
    
    # initialize the text label color as green (correct)
    color = (0, 255, 0)
 
    # otherwise, the class label prediction is incorrect
    if predicted_args[i] != y_test[i]:
        color = (255, 0, 0)
 
    # merge the channels into one image and resize the image from
    # 28x28 to 96x96 so we can better see it and then draw the
    # predicted label on the image
    image = cv.merge([image] * 3)
    image = cv.resize(image, (96, 96), interpolation=cv.INTER_LINEAR)
    cv.putText(image, class_names[y_test[i]], (5, 20), cv.FONT_HERSHEY_SIMPLEX, 0.75,
        color, 2)
 
    # add the image to our list of output images
    images.append(image)
 
# construct the montage for the images
montage = build_montages(images, (96, 96), (4, 4))[0]
 
# show the output montage
plt.imshow(montage, cmap=plt.cm.binary)
# cv.imshow("Fashion MNIST", montage)
# cv.waitKey(0)

# %% [markdown]
# ## Playing around with matplotlib

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)
    
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
num_rows = 4
num_cols = 4
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
j = 0
for i in random_choice:
    plt.subplot(num_rows, 2*num_cols, 2*j+1)
    plot_image(i, predictions[i], y_test, x_test)
    plt.subplot(num_rows, 2*num_cols, 2*j+2)
    plot_value_array(i, predictions[i], y_test)
    j += 1
plt.tight_layout()
plt.show()
